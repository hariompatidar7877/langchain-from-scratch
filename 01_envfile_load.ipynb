# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Pata karna ki hamari API load ho rahi hai ki nahi .env file se

# %%
import os

# %%
os.getenv("OPENAI_API_KEY")
# Out:
# 'Hariom'
